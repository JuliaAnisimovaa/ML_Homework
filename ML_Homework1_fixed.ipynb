# %% [markdown]
# Анисимова Юлия группа 3821Б1ПМоп2

# %% [markdown]
# #0. Описать задачу словами

# %% [markdown]
# Набор данных взят с Kaggle: https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction/?select=test.csv
#
# Набор данных состоит из 103904 и 25976 записей в обучающем и тестовом режимах соответственно. Данный набор данных содержит опрос об удовлетворенности авиапассажиров. Он состоит из 25 столбцов, таких как «Возраст», «Пол», «Класс путешествия», «Задержки прибытия и отправления», а также функций, влияющих на уровень удовлетворенности клиентов, таких как «Обслуживание на борту», «Чистота», «Комфорт сиденья», «Обработка багажа» и т.д. Набор данных состоит из столбца или функция под названием «удовлетворение» , которая описывает общий уровень удовлетворенности клиента. Он имеет два значения: «нейтральный или неудовлетворенный» и «удовлетворенный». Этот признак удовлетворенности считается признаком маркировки, поскольку он передает общее впечатление клиента на основе оценок.
#
# Таким образом, поставлена задача <b>классификации</b>: необходимо предсказать к какому из двух уровней удовлетворённости относится пассажир: «<b>нейтральный</b> или <b>неудовлетворенный</b>» и «<b>удовлетворенный</b>».
#
# Признаки.
#
# <b> 1. Gender </b>- Пол. Бинарный признак. Типы: Female (Женский), Male (Мужской).
#
# <b> 2. Customer Type</b>  - Тип клиента. Бинарный признак. Типы: Loyal customer (Лояльный клиент) и Disloyal customer (Нелояльный клиент).
# Лояльный клиент - это клиент, лояльный к авиакомпании, то есть чаще предпочитающий пользоваться услугами данной авиакомпании нежели другой. Нелояльный - чаще пользующийся услугами другой компании.
#
# <b> 3. Age</b> - Возраст. Количественный признак.
# <b> 4. Type of Travel </b>- Цель полета пассажира. Бинарный признак. Типы: Personal Travel (Личная поездка), Business Travel (Деловая поездка).
#
# <b> 5. Class</b> - Туристический класс, которым летит пассажир. Категориальный признак. Типы: Business (Бизнес), Eco (Эконом), Eco Plus (Эконом Плюс).
#
# <b> 6. Flight Distance </b> - Расстояние полета. Количественный признак.
#
# <b> 7. Inflight wifi service</b> - уровень удовлетворенности услугой Wi-Fi - от 1 до 5. Количественный признак.
#
# <b> 8. Departure/Arrival time convenient</b> - Уровень удовлетворенности тем, насколько удобно было время отправления/прибытия. Количественный признак.
#
# <b> 9. Ease of Online booking</b> - Уровень удовлетворенности простотой онлайн-бронирования. Количественный признак.
#
# <b> 10. Gate location</b> - Уровень удовлетворенности расположением выходов. Количественный признак.
#
# <b> 11. Food and drink </b>- Уровень удовлетворенности едой и напитками. Количественный признак.
#
# <b> 12. Online boarding</b> - Уровень удовлетворенности онлайн регистрацией на рейс. Количественный признак.
#
# <b> 13. Seat comfort </b>- Уровень удовлетворенности комфортабельностью кресел. Количественный признак.
#
# <b> 14. Inflight entertainment</b> - Уровень удовлетворенности развлечениями во время полета. Количественный признак.
#
# <b> 15. On-board service</b> - Уровень удовлетворенности услугами на борту. Количественный признак.
#
# <b> 16. Leg room service</b> - Уровень удовлетворенности количеством места для ног. Количественный признак.
#
# <b> 17. Baggage handling</b> - Уровень удовлетворенности услугами по транспортировке багажа. Количественный признак.
#
# <b> 18. Checkin service</b> - Уровень удовлетворенности услугой регистрации на рейс. Количественный признак.
#
# <b> 19. Inflight service</b> - Уровень удовлетворенности услугами во время полета. Количественный признак.
#
# <b> 20. Cleanliness</b> - Уровень удовлетворенности чистотой. Количественный признак.
#
# <b> 21. Departure Delay in Minutes </b> - Задержка отправления в минутах. Количественный признак.
#
# <b> 22. Arrival Delay in Minutes</b> - Задержка прибытия в минутах. Количественный признак.
#
# <b> 23. Satisfaction</b> - Уровень удовлетворенности. Бинарный признак. Типы: satisfaction, neutral or dissatisfied.

# %% [markdown]
# #1. Прочитать данные

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sns
import sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_train = pd.read_csv('/content/drive/My Drive/train.csv')
data_test = pd.read_csv('/content/drive/My Drive/test.csv')

# %%
data_raw = pd.concat([data_test, data_train])

# %%
data_raw.shape
# Out:
# (129880, 25)

# %%
data_raw.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'id',
#  'Gender',
#  'Customer Type',
#  'Age',
#  'Type of Travel',
#  'Class',
#  'Flight Distance',
#  'Inflight wifi service',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Gate location',
#  'Food and drink',
#  'Online boarding',
#  'Seat comfort',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Inflight service',
#  'Cleanliness',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes',
#  'satisfaction']

# %%
data_raw.head(10) #Данные в начале
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
# 5           5  39177    Male     Loyal Customer   16  Business travel
# 6           6  79433  Female     Loyal Customer   77  Business travel
# 7           7  97286  Female     Loyal Customer   43  Business travel
# 8           8  27508    Male     Loyal Customer   47  Business travel
# 9           9  62482  Female     Loyal Customer   46  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# ...

# %%
data_raw.tail(10) #Данные в конце
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 103894      103894   86549    Male     Loyal Customer   26  Business travel
# 103895      103895   66030  Female  disloyal Customer   24  Business travel
# 103896      103896   71445    Male     Loyal Customer   57  Business travel
# 103897      103897  102203  Female     Loyal Customer   60  Business travel
# 103898      103898   60666    Male     Loyal Customer   50  Personal Travel
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 103894  Business              712                      4
# ...

# %%
data_raw.info() # Выведем информацию в более читаемом виде
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129880 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         129880 non-null  int64
#  1   id                                 129880 non-null  int64
#  2   Gender                             129880 non-null  object
#  3   Customer Type                      129880 non-null  object
#  4   Age                                129880 non-null  int64
#  5   Type of Travel                     129880 non-null  object
#  6   Class                              129880 non-null  object
#  7   Flight Distance                    129880 non-null  int64
#  8   Inflight wifi service              129880 non-null  int64
#  9   Departure/Arrival time convenient  129880 non-null  int64
#  10  Ease of Online booking             129880 non-null  int64
# ...

# %% [markdown]
# <b>Вывод:</b> Имеются пропущенные значения. В столбце "Arrival Delay in Minutes" пропущено 393 значения. Признаки "Unnamed" и "id" не несут полезной информации и от них стоит избавиться.

# %%
data_raw = data_raw.drop(['Unnamed: 0', 'id'], axis = 1)

# %% [markdown]
# Столбцы 'Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction' содержат категориальные признаки. Необходимо заменить их тип 'Object' на специальный, предназначенный для хранения категориальных значений

# %%
data_raw['Gender'] = data_raw['Gender'].astype('category')
data_raw['Customer Type'] = data_raw['Customer Type'].astype('category')
data_raw['Type of Travel'] = data_raw['Type of Travel'].astype('category')
data_raw['Class'] = data_raw['Class'].astype('category')

# data_raw['Inflight wifi service'] = data_raw['Inflight wifi service'].astype('category')
# data_raw['Food and drink'] = data_raw['Food and drink'].astype('category')
# data_raw['Checkin service'] = data_raw['Checkin service'].astype('category')
# data_raw['Cleanliness'] = data_raw['Cleanliness'].astype('category')

data_raw.iloc[:,list(range(6, 20))] = data_raw.iloc[:,list(range(6, 20))].astype('category')

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129880 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129880 non-null  category
#  1   Customer Type                      129880 non-null  category
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  category
#  4   Class                              129880 non-null  category
#  5   Flight Distance                    129880 non-null  int64
#  6   Inflight wifi service              129880 non-null  category
#  7   Departure/Arrival time convenient  129880 non-null  category
#  8   Ease of Online booking             129880 non-null  category
#  9   Gate location                      129880 non-null  category
#  10  Food and drink                     129880 non-null  category
# ...

# %% [markdown]
# Приведем описание следующей таблице:
#
# *   count - количество значений для каждого признака;
# *   min/max - минимальное / макcимальное значение;
# *   mean - среднее значение;
# *   std - стандартное отклонение;
# *   25% - первый квартиль;
# *   50% - второй квартиль;
# *   75% - третий квартиль.

# %%
data_raw.describe()
# Out:
#                  Age  Flight Distance  Departure Delay in Minutes  \
# count  129880.000000    129880.000000               129880.000000
# mean       39.427957      1190.316392                   14.713713
# std        15.119360       997.452477                   38.071126
# min         7.000000        31.000000                    0.000000
# 25%        27.000000       414.000000                    0.000000
# 50%        40.000000       844.000000                    0.000000
# 75%        51.000000      1744.000000                   12.000000
# max        85.000000      4983.000000                 1592.000000
#
#        Arrival Delay in Minutes
# count             129487.000000
# mean                  15.091129
# std                   38.465650
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                   13.000000
# max                 1584.000000

# %% [markdown]
# #2. Визуализировать данные и вычислить основные характеристики (среднее, разброс, корреляционную матрицу и т.д.). Интерпретировать.

# %%
fig = plt.figure(figsize = (5, 5))
data_raw.satisfaction.value_counts(normalize = True).plot(kind='bar', color= ['darkorange','steelblue'], alpha = 0.9, rot=0)
plt.title('Индикатор удовлетворенности в наборе данных')
plt.show()

# %%
with sns.axes_style(style='ticks'):
    g = sns.catplot(
        x="satisfaction",
        col="Gender",
        col_wrap=2,
        data=data_raw,
        kind="count",
        height=2.5,
        aspect=2.3,
        palette={"satisfied": "steelblue", "neutral or dissatisfied": "darkorange"}
    )

plt.show()

# %% [markdown]
# <b>Вывод:</b> гендерное распределение нейтральных/неудовлетворенных и удовлетворенных клиентов схоже. Как для пассажиров мужского, так и для женского пола количество нейтральных/неудовлетворенных клиентов выше по сравнению с количеством довольных клиентов.

# %%
sns.catplot(
    x="satisfaction",
    col="Customer Type",
    col_wrap=2,
    data=data_raw,
    kind="count",
    height=2.5,
    aspect=2.3,
    palette={"satisfied": "steelblue", "neutral or dissatisfied": "darkorange"}
)
plt.show()

# %% [markdown]
# <b>Вывод:</b> Cреди лояльных пассажиров, которых много, соотношение довольных и нейтрально/недовольных почти близко

# %%
sns.catplot(
    x="Flight Distance",
    y="Type of Travel",
    hue="satisfaction",
    col="Class",
    data=data_raw,
    kind="bar",
    height=4.5,
    aspect=.8,
    palette={"satisfied": "steelblue", "neutral or dissatisfied": "darkorange"}
    )
plt.show()

# %% [markdown]
# <b>Вывод:</b> При поездках в категории бизнес-класса количество довольных пассажиров выше при больших расстояние полета. Для остальных комбинаций наблюдается почти равное распределение довольных и нейтрально/неудовлетворенных пассажиров.

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=data_raw, x="Age", hue="satisfaction", multiple="stack", kde=False)
plt.title("Distribution of Passenger Satisfaction by Age")
plt.xlabel("Age")
plt.ylabel("Count")
palette={"satisfied": "steelblue", "neutral or dissatisfied": "darkorange"}
plt.show()

# %% [markdown]
# <b>Вывод:</b>  Пассажиры в возрасте от 20 до 30 лет имеют высокий уровень неудовлетворенности. Пассажиры среднего возраста (примерно от 35 до 60 лет) демонстрируют более сбалансированное распределение между удовлетворенными и неудовлетворенными. В некоторых возрастных интервалах количество удовлетворенных пассажиров даже превышает неудовлетворенных.Старшие возрастные группы (от 60 лет и старше) также имеют более высокую долю неудовлетворенных пассажиров.

# %%
numerical_data = data_raw.select_dtypes(include=['number'])

# Вычисление корреляционной матрицы
corr_matrix = numerical_data.corr()

# Построение тепловой карты для корреляционной матрицы
plt.figure(figsize=(5, 4))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Correlation Matrix of Features")
plt.show()

# %% [markdown]
# <b>Вывод:</b> Наибольший интерес представляет высокая корреляция между "Departure Delay in Minutes" и "Arrival Delay in Minutes", что логично и имеет практическое значение. Остальные корреляции являются слабыми, что указывает на слабую или незначимую зависимость между этими признаками.

# %% [markdown]
# #3. Обработать пропущенные знаечения

# %% [markdown]
# Было выяснено, что пропущенно 393 значений в 'Arrival Delay in Minutes'. Убедимся в этом еще раз:

# %%
total = data_raw.isnull().sum().sort_values(ascending=False)
percent = (data_raw.isnull().sum()/data_raw.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing.head()
# Out:
#                             Total   Percent
# Arrival Delay in Minutes      393  0.003026
# Gender                          0  0.000000
# Seat comfort                    0  0.000000
# Departure Delay in Minutes      0  0.000000
# Cleanliness                     0  0.000000

# %% [markdown]
# Заполним пропущенные значения:

# %%
data_raw['Arrival Delay in Minutes'].fillna(data_raw['Arrival Delay in Minutes'].median(axis = 0), axis=0 , inplace=True)

# %% [markdown]
# Приведем описание таблице ниже, которая описывает категориальные признаки. Здесь :
# *   top - наиболее встречающееся значение;
# *   freq - частота наиболее встречающегося значения;
# *   count - количество значений;
# *   unique - количество уникальных значений.

# %%
data_describe = data_raw.describe(include=['category'])
data_describe
# Out:
#         Gender   Customer Type   Type of Travel     Class  \
# count   129880          129880           129880    129880
# unique       2               2                2         3
# top     Female  Loyal Customer  Business travel  Business
# freq     65899          106100            89693     62160
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# count                  129880                             129880
# unique                      6                                  6
# top                         2                                  4
# freq                    32320                              31880
#
#         Ease of Online booking  Gate location  Food and drink  \
# count                   129880         129880          129880
# unique                       6              6               6
# top                          3              3               4
# freq                     30393          35717           30563
#
# ...

# %% [markdown]
# Видно, что есть признаки, которые небинарные, поэтому проведём обработку категориальных значений.

# %% [markdown]
# #4. Обработать категориальные признаки

# %%
categ_columns = [c for c in data_raw.columns if data_raw[c].dtype.name == 'category']
categ_columns
# Out:
# ['Gender',
#  'Customer Type',
#  'Type of Travel',
#  'Class',
#  'Inflight wifi service',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Gate location',
#  'Food and drink',
#  'Online boarding',
#  'Seat comfort',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Inflight service',
#  'Cleanliness']

# %% [markdown]
# Рассмотрим бинарные признаки:

# %%
categorical_columns = [c for c in data_raw.columns if data_raw[c].dtype.name == 'category']; describe = data_raw.describe(include=['category'])

# %%
for col in categ_columns:
    if describe[col]['unique'] == 2:
        data_raw[col] = data_raw[col].astype('category')
        data_raw[col] = data_raw[col].cat.codes

# %% [markdown]
# Рассмотри небинарные признаки:

# %%
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
nonbinary = pd.get_dummies(data_raw[nonbinary_columns])

# %% [markdown]
# #5. Провести нормализацию

# %% [markdown]
# Некоторые алгоритмы машинного обучения чувствительны к масштабированию данных,например, метод ближайших соседей, метод опорных векторов и т.д.

# %% [markdown]
# Из прошлых пунктов, исходя из матрицы корреляции видно, что между признаками "Departure Delay in Minutes" и "Arrival Delay in Minutes" высокая корреляция. Можно удалить один признак из пары сильно коррелирующих признаков для того, чтобы уменьшить число рассматриваемых признаков. То есть можно удалить признак Arrival Delay in Minutes.

# %%
data_raw.drop("Arrival Delay in Minutes", axis =1, inplace= True)

# %%
num_columns = [c for c in data_raw.columns if data_raw[c].dtype.name != 'category' and c != 'satisfaction' ]
data_numerical = data_raw[num_columns]

# %%
data_raw[num_columns] = (data_raw[num_columns] - data_raw[num_columns].mean(axis = 0))/data_raw[num_columns].std(axis = 0)
data_raw.describe()
# Out:
#              Gender  Customer Type           Age  Type of Travel  \
# count  1.298800e+05   1.298800e+05  1.298800e+05    1.298800e+05
# mean  -7.128405e-17   7.396472e-17 -8.545332e-17    5.268345e-17
# std    1.000000e+00   1.000000e+00  1.000000e+00    1.000000e+00
# min   -9.853362e-01  -4.734200e-01 -2.144797e+00   -6.693632e-01
# 25%   -9.853362e-01  -4.734200e-01 -8.219896e-01   -6.693632e-01
# 50%   -9.853362e-01  -4.734200e-01  3.783516e-02   -6.693632e-01
# 75%    1.014874e+00  -4.734200e-01  7.653792e-01    1.493946e+00
# max    1.014874e+00   2.112273e+00  3.014152e+00    1.493946e+00
#
#        Flight Distance  Departure Delay in Minutes
# count     1.298800e+05                1.298800e+05
# mean      9.103350e-17                7.659069e-18
# std       1.000000e+00                1.000000e+00
# min      -1.162277e+00               -3.864796e-01
# 25%      -7.782991e-01               -3.864796e-01
# 50%      -3.472009e-01               -3.864796e-01
# ...

# %% [markdown]
# Соберём все данные:

# %%
Y= data_raw['satisfaction']

# %%
binary_columns = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
data_raw = pd.concat((data_raw[num_columns], nonbinary, data_raw[binary_columns]), axis = 1)

# %% [markdown]
# #6. Разбить данные на обучающую и тестовую выборки

# %%
X = data_raw
X.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Flight Distance',
#        'Departure Delay in Minutes', 'Class_Business', 'Class_Eco',
#        'Class_Eco Plus', 'Inflight wifi service_0', 'Inflight wifi service_1',
#        'Inflight wifi service_2', 'Inflight wifi service_3',
#        'Inflight wifi service_4', 'Inflight wifi service_5',
#        'Departure/Arrival time convenient_0',
#        'Departure/Arrival time convenient_1',
#        'Departure/Arrival time convenient_2',
#        'Departure/Arrival time convenient_3',
#        'Departure/Arrival time convenient_4',
#        'Departure/Arrival time convenient_5', 'Ease of Online booking_0',
#        'Ease of Online booking_1', 'Ease of Online booking_2',
#        'Ease of Online booking_3', 'Ease of Online booking_4',
#        'Ease of Online booking_5', 'Gate location_0', 'Gate location_1',
#        'Gate location_2', 'Gate location_3', 'Gate location_4',
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt



X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

print("Размер обучающей выборки:", X_train.shape)
print("Размер тестовой выборки:", X_test.shape)
# Out:
# Размер обучающей выборки: (97410, 95)
# Размер тестовой выборки: (32470, 95)

# %% [markdown]
# #7. Запустить классификатор (регрессию) ближайших соседей

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
search = GridSearchCV(KNeighborsClassifier(), param_grid={'n_neighbors': range(1, 21)}, cv=5, n_jobs=-1).fit(X_train, y_train)

print(1 - search.best_score_)
print( search.best_estimator_.n_neighbors)
# Out:
# 0.0641720562570578
# 7

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

kNNf = KNeighborsClassifier()
kNNf.n_neighbors = search.best_estimator_.n_neighbors
kNNf.fit(X_train, y_train)

y_train_prediction = kNNf.predict(X_train)
y_test_prediction = kNNf.predict(X_test)
cm = confusion_matrix(y_train, y_train_prediction)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=kNNf.classes_)
disp.plot()

# %%
print(classification_report(y_test, y_test_prediction))
# Out:
#                          precision    recall  f1-score   support
#
# neutral or dissatisfied       0.94      0.96      0.95     18226
#               satisfied       0.94      0.92      0.93     14244
#
#                accuracy                           0.94     32470
#               macro avg       0.94      0.94      0.94     32470
#            weighted avg       0.94      0.94      0.94     32470

# %%
err_train = np.mean(y_train != kNNf.predict(X_train))
err_test  = np.mean(y_test  != kNNf.predict(X_test))

# %%
print(err_train, err_test)
# Out:
# 0.048105943948259934 0.06033261472128118

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.03591007083461657

# %% [markdown]
# <b>Вывод:</b> Безусловно, алгоритм Random Forest лучше справляется с задачей, чем метод ближайших соседей (KNN), так как его ошибка на тестовой выборке ниже.
#
# Ошибки: 0.0 на обучающей выборке и 0.0357 на тестовой выборке для Random Forest; для KNN — 0.048 на обучающей и 0.060 на тестовой.

# %% [markdown]
# Сделаем подбор гиперпараметра "alfa" для нейронной сети MLP (Multi-layer Perceptron)

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
train_acc = []
test_acc = []

for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (3,),
                              solver = 'lbfgs', activation = 'logistic', max_iter=1000, random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)

    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))
    train_acc.append(accuracy_score(y_train, y_train_pred))
    test_acc.append(accuracy_score(y_test, y_test_pred))

# %%
plt.semilogx(alpha_arr, train_err, 'b-o', label = 'train')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.min(alpha_arr), np.max(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('Alpha')
plt.ylabel('Error')
plt.legend()
pass

# %% [markdown]
# График показывает, как ошибка изменяется в зависимости от гиперпараметра

# %%
plt.semilogx(alpha_arr, train_acc, 'r-o', label = 'train')
plt.semilogx(alpha_arr, test_acc, 'b-o', label = 'test')
plt.xlim([np.min(alpha_arr), np.max(alpha_arr)])
plt.title('Accuracy vs. alpha')
plt.xlabel('alpha')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# График показывает, как изменяется точность модели

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print('Минимальная ошибка train: ', min_train_err)
print('Минимальная ошибка test: ', min_test_err)
# Out:
# Минимальная ошибка train:  0.04207986859665332
# Минимальная ошибка test:  0.04228518632583923

# %%
alpha_opt = alpha_arr[test_err == min_test_err][0]

# %%
alpha_opt
# Out:
# 1.7782794100389228

# %% [markdown]
# Сеть снова обучается с найденным значением alpha
# Вычисляются ошибки на обучающей и тестовой выборках:

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (3,),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred))
print(np.mean(y_test != y_test_pred))
# Out:
# 0.04207986859665332
# 0.04228518632583923

# %% [markdown]
# Ошибки на обучении и тестировании близки, что указывает на отсутствие переобучения.

# %% [markdown]
#  Построение матрицы ошибок (Confusion Matrix)

# %%
print(confusion_matrix(y_test_pred, y_test))
# Out:
# [[17843   990]
#  [  383 13254]]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Построение матрицы ошибок вручную
cm = confusion_matrix(y_test, mlp_model.predict(X_test))

# Визуализация с помощью Seaborn
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['neutral or dissatisfied', 'satisfied'], yticklabels=['neutral or dissatisfied', 'satisfied'])
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Для сравнения производительности используем LogisticRegression

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#                          precision    recall  f1-score   support
#
# neutral or dissatisfied       0.95      0.98      0.96     18226
#               satisfied       0.97      0.93      0.95     14244
#
#                accuracy                           0.96     32470
#               macro avg       0.96      0.95      0.96     32470
#            weighted avg       0.96      0.96      0.96     32470

# %%
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression(random_state = 42,solver = 'newton-cg')
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42, solver='newton-cg')

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Получаем матрицу ошибок
cm = confusion_matrix(y_test, model_lr.predict(X_test))

# Визуализация с помощью Seaborn
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['neutral or dissatisfied', 'satisfied'],
            yticklabels=['neutral or dissatisfied', 'satisfied'])
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %%
y_train_pred = model_lr.predict(X_train)
y_test_pred = model_lr.predict(X_test)
print(np.mean(y_train != y_train_pred))
print(np.mean(y_test != y_test_pred))
# Out:
# 0.06662560312082948
# 0.06698490914690483

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#                          precision    recall  f1-score   support
#
# neutral or dissatisfied       0.93      0.95      0.94     18226
#               satisfied       0.93      0.91      0.92     14244
#
#                accuracy                           0.93     32470
#               macro avg       0.93      0.93      0.93     32470
#            weighted avg       0.93      0.93      0.93     32470

# %% [markdown]
# <b>Вывод:</b> Ошибки на обучающей и тестовой выборках для логистической регрессии:
#
# *   Ошибка на обучающей выборке: 0.0666 (≈ 6.66%);
# *   Ошибка на тестовой выборке: 0.0669 (≈ 6.69%).
#
# В предыдущем эксперименте с нейронной сетью (MLPClassifier) были получены более низкие ошибки:
#
# *   Ошибка на обучающей выборке: 0.0421 (≈ 4.21%);
# *   Ошибка на тестовой выборке: 0.0422 (≈ 4.22%).
#
# Таким образом, нейронная сеть показывает лучшие результаты, чем логистическая регрессия. Разница в ошибках составляет примерно 2.4%, что указывает на более высокое качество классификации нейронной сети.
#
# Наименьшая ошибка была достигнута при параметре alpha ≈ 1.778279

# %% [markdown]
# С теми же данными решить задачу кластеризации методом KMeans

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix, accuracy_score, adjusted_rand_score
from sklearn.preprocessing import LabelEncoder
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

label_encoder = LabelEncoder()
y_test_encoded = label_encoder.fit_transform(y_test)

kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X_train)

train_clusters = kmeans.predict(X_train)
test_clusters = kmeans.predict(X_test)

test_clusters = np.where(test_clusters == 0, 1, 0)

kmeans_error = np.mean(test_clusters != y_test_encoded)

print("Ошибка на тестовой выборке (KMeans): {:.2%}".format(kmeans_error))

accuracy = accuracy_score(y_test_encoded, test_clusters)
print("Точность на тестовой выборке (KMeans): {:.2%}".format(accuracy))

cm = confusion_matrix(y_test_encoded, test_clusters)
print("\nМатрица ошибок (Confusion Matrix):")
print(cm)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.title("Confusion Matrix KMeans vs True Labels")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

ari_score = adjusted_rand_score(y_test_encoded, test_clusters)
print("Adjusted Rand Index (ARI):", ari_score)
# Out:
# Ошибка на тестовой выборке (KMeans): 22.40%
# Точность на тестовой выборке (KMeans): 77.60%
#
# Матрица ошибок (Confusion Matrix):
# [[13358  4868]
#  [ 2406 11838]]
# Adjusted Rand Index (ARI): 0.3046251620964083

# %% [markdown]
# <b>Вывод:</b>
#
# Ошибка 22.4% значительно выше по сравнению с методами обучения с учителем.
# Причина заключается в том, что KMeans работает без использования целевых меток и разделяет данные только на основе геометрических признаков.
#
# Методы обучения с учителем (нейронная сеть и логистическая регрессия) значительно превосходят KMeans
